# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        timestamp = city_weather['dt']
        # Convert date format from Unix to UTC
        utc_date_struct = time.gmtime(timestamp)
        city_date = time.strftime('%m/%d/%Y', utc_date_struct)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | st. john's
# Processing Record 3 of Set 1 | takamaka
# City not found. Skipping...
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | preobrazheniye
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | haiku-pauwela
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | namsos
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | newman
# Processing Record 14 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 15 of Set 1 | sur
# Processing Record 16 of Set 1 | brokopondo
# Processing Record 17 of Set 1 | wailua homesteads
# Processing Record 18 of Set 1 | igrim
# Processing Record 19 of Set 1 | dalhart
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | lazaro cardenas
# Processing Record 22 of Set 1 | stanley
# Processing Record 23 of Set 1 | olonkinbyen
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | atafu village
# Processing Record 26 of Set 1 | marka
# Processing Record 27 of Set 1 | invercargill
# Processing Record 28 of Set 1 | iranshahr
# Processing Record 29 of Set 1 | morgan city
# Processing Record 30 of Set 1 | namibe
# Processing Record 31 of Set 1 | kingston
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | kataragama
# City not found. Skipping...
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | riverside
# Processing Record 37 of Set 1 | chibougamau
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | bejaia
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | grytviken
# Processing Record 44 of Set 1 | solnechnyy
# Processing Record 45 of Set 1 | kailua-kona
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | utrik
# Processing Record 48 of Set 1 | enewetak
# Processing Record 49 of Set 1 | urengoy
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | nizhniy ingash
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | west island
# Processing Record 4 of Set 2 | prince rupert
# Processing Record 5 of Set 2 | castillos
# Processing Record 6 of Set 2 | mosjoen
# Processing Record 7 of Set 2 | yelizovo
# Processing Record 8 of Set 2 | whitehorse
# Processing Record 9 of Set 2 | mount pearl
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | waitangi
# Processing Record 12 of Set 2 | nyala
# Processing Record 13 of Set 2 | nadi
# Processing Record 14 of Set 2 | puerto aysen
# Processing Record 15 of Set 2 | baiyin
# Processing Record 16 of Set 2 | nikolayevsk-on-amure
# Processing Record 17 of Set 2 | port mathurin
# Processing Record 18 of Set 2 | sullivan
# Processing Record 19 of Set 2 | sault ste. marie
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | holualoa
# Processing Record 22 of Set 2 | qaqortoq
# Processing Record 23 of Set 2 | moranbah
# Processing Record 24 of Set 2 | papatowai
# Processing Record 25 of Set 2 | khark
# Processing Record 26 of Set 2 | sabang
# Processing Record 27 of Set 2 | bardai
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | pyetrykaw
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | chernyshevsk
# Processing Record 32 of Set 2 | laguna
# Processing Record 33 of Set 2 | edinburgh of the seven seas
# Processing Record 34 of Set 2 | zhezqazghan
# Processing Record 35 of Set 2 | coahuayana de hidalgo
# Processing Record 36 of Set 2 | mandiana
# Processing Record 37 of Set 2 | yokadouma
# Processing Record 38 of Set 2 | fale old settlement
# Processing Record 39 of Set 2 | filadelfia
# Processing Record 40 of Set 2 | kaga bandoro
# Processing Record 41 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 2 | keflavik
# Processing Record 43 of Set 2 | nuevo casas grandes
# Processing Record 44 of Set 2 | susuman
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | polyarnyy
# Processing Record 47 of Set 2 | kapuskasing
# Processing Record 48 of Set 2 | khorugh
# Processing Record 49 of Set 2 | kuah
# Processing Record 50 of Set 2 | constantia
# Processing Record 1 of Set 3 | palapye
# Processing Record 2 of Set 3 | praia da vitoria
# Processing Record 3 of Set 3 | kalmunai
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | ilebo
# Processing Record 6 of Set 3 | puerto natales
# Processing Record 7 of Set 3 | escanaba
# Processing Record 8 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 3 | coquimbo
# Processing Record 10 of Set 3 | rondonopolis
# Processing Record 11 of Set 3 | sao miguel do iguacu
# Processing Record 12 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 3 | brisas de zicatela
# Processing Record 14 of Set 3 | tolanaro
# Processing Record 15 of Set 3 | krasnoslobodsk
# Processing Record 16 of Set 3 | dongsheng
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | blackmans bay
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | saipan
# Processing Record 21 of Set 3 | dunedin
# Processing Record 22 of Set 3 | ruwandiz
# Processing Record 23 of Set 3 | santa elena de uairen
# Processing Record 24 of Set 3 | meadow lakes
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | turbat
# Processing Record 27 of Set 3 | vorgashor
# Processing Record 28 of Set 3 | udachny
# Processing Record 29 of Set 3 | puerto ayora
# Processing Record 30 of Set 3 | margaret river
# Processing Record 31 of Set 3 | leua
# Processing Record 32 of Set 3 | vondrozo
# Processing Record 33 of Set 3 | kijang
# Processing Record 34 of Set 3 | pointe-noire
# Processing Record 35 of Set 3 | badger
# Processing Record 36 of Set 3 | chonchi
# Processing Record 37 of Set 3 | sandnessjoen
# Processing Record 38 of Set 3 | weno
# Processing Record 39 of Set 3 | hassi messaoud
# Processing Record 40 of Set 3 | northam
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | san luis de la loma
# Processing Record 43 of Set 3 | hamilton
# Processing Record 44 of Set 3 | cill airne
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | lihue
# Processing Record 47 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | box elder
# Processing Record 50 of Set 3 | lata
# Processing Record 1 of Set 4 | mili
# Processing Record 2 of Set 4 | little cayman
# City not found. Skipping...
# Processing Record 3 of Set 4 | mira monte
# Processing Record 4 of Set 4 | thinadhoo
# Processing Record 5 of Set 4 | leeton
# Processing Record 6 of Set 4 | fort bragg
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | nishinoomote
# Processing Record 9 of Set 4 | guskhara
# Processing Record 10 of Set 4 | amurzet
# Processing Record 11 of Set 4 | laascaanood
# Processing Record 12 of Set 4 | portland
# Processing Record 13 of Set 4 | t'aebaek
# Processing Record 14 of Set 4 | huinca renanco
# Processing Record 15 of Set 4 | tsetserleg
# Processing Record 16 of Set 4 | zakharivka
# Processing Record 17 of Set 4 | usogorsk
# Processing Record 18 of Set 4 | nova sintra
# Processing Record 19 of Set 4 | isafjordur
# Processing Record 20 of Set 4 | bhongir
# Processing Record 21 of Set 4 | ovria
# Processing Record 22 of Set 4 | chikwawa
# Processing Record 23 of Set 4 | arawa
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | metro
# Processing Record 26 of Set 4 | laikit, laikit ii (dimembe)
# Processing Record 27 of Set 4 | general mosconi
# Processing Record 28 of Set 4 | wagar
# Processing Record 29 of Set 4 | santa terezinha
# Processing Record 30 of Set 4 | easton
# Processing Record 31 of Set 4 | cienfuegos
# Processing Record 32 of Set 4 | gambiran satu
# Processing Record 33 of Set 4 | whakatane
# Processing Record 34 of Set 4 | ravar
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | panaba
# Processing Record 37 of Set 4 | sao vicente
# Processing Record 38 of Set 4 | papao
# Processing Record 39 of Set 4 | winslow
# Processing Record 40 of Set 4 | fada
# Processing Record 41 of Set 4 | mournies
# Processing Record 42 of Set 4 | gadzhiyevo
# Processing Record 43 of Set 4 | tidjikja
# Processing Record 44 of Set 4 | saint-pierre
# Processing Record 45 of Set 4 | aasiaat
# Processing Record 46 of Set 4 | fisterra
# Processing Record 47 of Set 4 | buala
# Processing Record 48 of Set 4 | jinchang
# Processing Record 49 of Set 4 | kone
# Processing Record 50 of Set 4 | palmer
# Processing Record 1 of Set 5 | kirensk
# Processing Record 2 of Set 5 | cuito
# Processing Record 3 of Set 5 | kaspiyskiy
# Processing Record 4 of Set 5 | chicxulub puerto
# City not found. Skipping...
# Processing Record 5 of Set 5 | nicoya
# Processing Record 6 of Set 5 | jamestown
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | salekhard
# Processing Record 9 of Set 5 | belmonte
# Processing Record 10 of Set 5 | quibdo
# Processing Record 11 of Set 5 | cole harbour
# Processing Record 12 of Set 5 | bucerias
# Processing Record 13 of Set 5 | klyuchi
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | nelson bay
# Processing Record 16 of Set 5 | hawaiian paradise park
# Processing Record 17 of Set 5 | mpika
# Processing Record 18 of Set 5 | majene
# Processing Record 19 of Set 5 | taroudant
# Processing Record 20 of Set 5 | san rafael
# Processing Record 21 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 22 of Set 5 | bageshwar
# Processing Record 23 of Set 5 | san juan
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | waingapu
# Processing Record 26 of Set 5 | pervomayskoye
# Processing Record 27 of Set 5 | hanceville
# Processing Record 28 of Set 5 | island harbour
# Processing Record 29 of Set 5 | puerto lempira
# Processing Record 30 of Set 5 | lashio
# Processing Record 31 of Set 5 | n'dalatando
# Processing Record 32 of Set 5 | patterson
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | vilyuchinsk
# Processing Record 36 of Set 5 | santa cruz
# Processing Record 37 of Set 5 | hermanus
# Processing Record 38 of Set 5 | ipu
# Processing Record 39 of Set 5 | sona
# Processing Record 40 of Set 5 | ust-nera
# Processing Record 41 of Set 5 | iskateley
# Processing Record 42 of Set 5 | hawsh 'isa
# City not found. Skipping...
# Processing Record 43 of Set 5 | kaladhungi
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | kurayoshi
# Processing Record 46 of Set 5 | gamboma
# Processing Record 47 of Set 5 | teknaf
# Processing Record 48 of Set 5 | ashland
# Processing Record 49 of Set 5 | handan
# Processing Record 50 of Set 5 | alesund
# Processing Record 1 of Set 6 | okha
# Processing Record 2 of Set 6 | healesville
# Processing Record 3 of Set 6 | ola
# Processing Record 4 of Set 6 | jaguaruna
# Processing Record 5 of Set 6 | xocali
# Processing Record 6 of Set 6 | urumqi
# Processing Record 7 of Set 6 | duncan town
# City not found. Skipping...
# Processing Record 8 of Set 6 | flying fish cove
# Processing Record 9 of Set 6 | nantucket
# Processing Record 10 of Set 6 | nizhnesortymskiy
# Processing Record 11 of Set 6 | cradock
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | hirara
# Processing Record 14 of Set 6 | scottsbluff
# Processing Record 15 of Set 6 | farasan
# Processing Record 16 of Set 6 | elmendorf air force base
# City not found. Skipping...
# Processing Record 17 of Set 6 | magdagachi
# Processing Record 18 of Set 6 | parabel'
# Processing Record 19 of Set 6 | messias
# Processing Record 20 of Set 6 | ribadesella
# Processing Record 21 of Set 6 | hithadhoo
# Processing Record 22 of Set 6 | sisimiut
# Processing Record 23 of Set 6 | rio gallegos
# Processing Record 24 of Set 6 | tarabha
# Processing Record 25 of Set 6 | itoman
# Processing Record 26 of Set 6 | oualidia
# City not found. Skipping...
# Processing Record 27 of Set 6 | prado
# Processing Record 28 of Set 6 | villa gesell
# Processing Record 29 of Set 6 | valparaiso
# Processing Record 30 of Set 6 | saint-philippe
# Processing Record 31 of Set 6 | gazojak
# Processing Record 32 of Set 6 | sao gabriel da cachoeira
# Processing Record 33 of Set 6 | mhamid
# Processing Record 34 of Set 6 | coronel dorrego
# Processing Record 35 of Set 6 | rikaze
# Processing Record 36 of Set 6 | khandud
# Processing Record 37 of Set 6 | mongoumba
# Processing Record 38 of Set 6 | shalqar
# Processing Record 39 of Set 6 | freetown
# Processing Record 40 of Set 6 | balabac
# Processing Record 41 of Set 6 | ancud
# Processing Record 42 of Set 6 | along
# Processing Record 43 of Set 6 | kangding
# Processing Record 44 of Set 6 | vadso
# Processing Record 45 of Set 6 | wamba
# Processing Record 46 of Set 6 | benguela
# Processing Record 47 of Set 6 | paita
# Processing Record 48 of Set 6 | tura
# Processing Record 49 of Set 6 | hoa binh
# Processing Record 50 of Set 6 | lyubinskiy
# Processing Record 1 of Set 7 | olinda
# Processing Record 2 of Set 7 | shakawe
# Processing Record 3 of Set 7 | arno
# Processing Record 4 of Set 7 | amarante do maranhao
# Processing Record 5 of Set 7 | saudarkrokur
# Processing Record 6 of Set 7 | siyabuswa
# Processing Record 7 of Set 7 | kill devil hills
# Processing Record 8 of Set 7 | nizhneudinsk
# Processing Record 9 of Set 7 | lompoc
# Processing Record 10 of Set 7 | iwanai
# Processing Record 11 of Set 7 | ukhta
# Processing Record 12 of Set 7 | kargasok
# Processing Record 13 of Set 7 | labytnangi
# Processing Record 14 of Set 7 | greymouth
# Processing Record 15 of Set 7 | nookat
# City not found. Skipping...
# Processing Record 16 of Set 7 | marsa alam
# Processing Record 17 of Set 7 | baniachang
# Processing Record 18 of Set 7 | tremonton
# Processing Record 19 of Set 7 | ta`u
# Processing Record 20 of Set 7 | kulhudhuffushi
# Processing Record 21 of Set 7 | ca mau
# Processing Record 22 of Set 7 | akureyri
# Processing Record 23 of Set 7 | tralee
# Processing Record 24 of Set 7 | natal
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | antonio enes
# Processing Record 27 of Set 7 | vila franca do campo
# Processing Record 28 of Set 7 | nadym
# Processing Record 29 of Set 7 | inhambane
# Processing Record 30 of Set 7 | kon tum
# Processing Record 31 of Set 7 | el granada
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | ad dilam
# Processing Record 34 of Set 7 | tostado
# Processing Record 35 of Set 7 | ranong
# Processing Record 36 of Set 7 | mezhova
# Processing Record 37 of Set 7 | queenstown
# Processing Record 38 of Set 7 | saltillo
# Processing Record 39 of Set 7 | kalemie
# Processing Record 40 of Set 7 | kokopo
# Processing Record 41 of Set 7 | howard springs
# Processing Record 42 of Set 7 | boden
# Processing Record 43 of Set 7 | winburg
# Processing Record 44 of Set 7 | revda
# Processing Record 45 of Set 7 | musoma
# Processing Record 46 of Set 7 | pama
# Processing Record 47 of Set 7 | saint-francois
# Processing Record 48 of Set 7 | conception bay south
# Processing Record 49 of Set 7 | nova vicosa
# Processing Record 50 of Set 7 | dickinson
# Processing Record 1 of Set 8 | avon
# Processing Record 2 of Set 8 | misawa
# Processing Record 3 of Set 8 | hoxtolgay
# City not found. Skipping...
# Processing Record 4 of Set 8 | xacmaz
# Processing Record 5 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 6 of Set 8 | fort mcmurray
# Processing Record 7 of Set 8 | masterton
# Processing Record 8 of Set 8 | la passe
# Processing Record 9 of Set 8 | vitoria da conquista
# Processing Record 10 of Set 8 | tabou
# Processing Record 11 of Set 8 | brookings
# Processing Record 12 of Set 8 | ocumare del tuy
# Processing Record 13 of Set 8 | eyl
# Processing Record 14 of Set 8 | manga
# Processing Record 15 of Set 8 | sierra grande
# Processing Record 16 of Set 8 | nemuro
# Processing Record 17 of Set 8 | kristiansund
# Processing Record 18 of Set 8 | colonia menno
# Processing Record 19 of Set 8 | pacific grove
# Processing Record 20 of Set 8 | ballina
# Processing Record 21 of Set 8 | jayapura
# Processing Record 22 of Set 8 | usinsk
# Processing Record 23 of Set 8 | porto novo
# Processing Record 24 of Set 8 | puerto armuelles
# Processing Record 25 of Set 8 | antalaha
# Processing Record 26 of Set 8 | kiunga
# Processing Record 27 of Set 8 | nagqu
# Processing Record 28 of Set 8 | trincomalee
# Processing Record 29 of Set 8 | takum
# Processing Record 30 of Set 8 | broken hill
# Processing Record 31 of Set 8 | idabel
# Processing Record 32 of Set 8 | midvagur
# Processing Record 33 of Set 8 | hastings
# Processing Record 34 of Set 8 | umluj
# Processing Record 35 of Set 8 | quellon
# Processing Record 36 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 37 of Set 8 | tegueste
# Processing Record 38 of Set 8 | birjand
# Processing Record 39 of Set 8 | trairi
# Processing Record 40 of Set 8 | hadibu
# Processing Record 41 of Set 8 | cao bang
# Processing Record 42 of Set 8 | monticello
# Processing Record 43 of Set 8 | al ghayzah
# Processing Record 44 of Set 8 | tsiombe
# Processing Record 45 of Set 8 | labrador city
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | zhongshu
# Processing Record 48 of Set 8 | marsh harbour
# Processing Record 49 of Set 8 | al fuwayliq
# Processing Record 50 of Set 8 | raub
# Processing Record 1 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 2 of Set 9 | estevan
# Processing Record 3 of Set 9 | pathein
# Processing Record 4 of Set 9 | copiapo
# Processing Record 5 of Set 9 | vila do maio
# Processing Record 6 of Set 9 | geneina
# Processing Record 7 of Set 9 | callao
# Processing Record 8 of Set 9 | egilsstadir
# Processing Record 9 of Set 9 | raduzhny
# Processing Record 10 of Set 9 | punta del este
# Processing Record 11 of Set 9 | bouna
# Processing Record 12 of Set 9 | port macquarie
# Processing Record 13 of Set 9 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | byron
# Processing Record 15 of Set 9 | uturoa
# Processing Record 16 of Set 9 | as sulayyil
# Processing Record 17 of Set 9 | mancora
# Processing Record 18 of Set 9 | westport
# Processing Record 19 of Set 9 | tazacorte
# Processing Record 20 of Set 9 | astrakhan
# Processing Record 21 of Set 9 | les cayes
# Processing Record 22 of Set 9 | guapore
# Processing Record 23 of Set 9 | puerto gaitan
# Processing Record 24 of Set 9 | south hedland
# Processing Record 25 of Set 9 | umba
# Processing Record 26 of Set 9 | abraham's bay
# City not found. Skipping...
# Processing Record 27 of Set 9 | naryn
# Processing Record 28 of Set 9 | bileh savar
# City not found. Skipping...
# Processing Record 29 of Set 9 | tazovsky
# Processing Record 30 of Set 9 | huarmey
# Processing Record 31 of Set 9 | ilheus
# Processing Record 32 of Set 9 | las brenas
# Processing Record 33 of Set 9 | jobabo
# Processing Record 34 of Set 9 | orumiyeh
# Processing Record 35 of Set 9 | garissa
# Processing Record 36 of Set 9 | arraial do cabo
# Processing Record 37 of Set 9 | lamu
# Processing Record 38 of Set 9 | labasa
# Processing Record 39 of Set 9 | jiuquan
# Processing Record 40 of Set 9 | lundazi
# Processing Record 41 of Set 9 | nyurba
# Processing Record 42 of Set 9 | barranca
# Processing Record 43 of Set 9 | beaufort
# Processing Record 44 of Set 9 | dongning
# Processing Record 45 of Set 9 | san antonio de pale
# Processing Record 46 of Set 9 | madalena
# Processing Record 47 of Set 9 | sawakin
# Processing Record 48 of Set 9 | nizhniy odes
# Processing Record 49 of Set 9 | sabzevar
# Processing Record 50 of Set 9 | ouargla
# Processing Record 1 of Set 10 | pionerskiy
# Processing Record 2 of Set 10 | saqqez
# Processing Record 3 of Set 10 | camaqua
# Processing Record 4 of Set 10 | carbonear
# Processing Record 5 of Set 10 | winnipeg
# Processing Record 6 of Set 10 | yulinshi
# Processing Record 7 of Set 10 | el-tor
# Processing Record 8 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 10 | hagere hiywet
# Processing Record 10 of Set 10 | stafford
# Processing Record 11 of Set 10 | tahe
# Processing Record 12 of Set 10 | emerald
# Processing Record 13 of Set 10 | ust-tsilma
# Processing Record 14 of Set 10 | mazagao
# Processing Record 15 of Set 10 | dalbandin
# Processing Record 16 of Set 10 | richards bay
# Processing Record 17 of Set 10 | opuwo
# Processing Record 18 of Set 10 | namtsy
# Processing Record 19 of Set 10 | villanueva
# Processing Record 20 of Set 10 | mogocha
# Processing Record 21 of Set 10 | hobyo
# Processing Record 22 of Set 10 | kuta
# Processing Record 23 of Set 10 | sittwe
# Processing Record 24 of Set 10 | zhalantun
# Processing Record 25 of Set 10 | chernyshevskiy
# Processing Record 26 of Set 10 | salinas
# Processing Record 27 of Set 10 | berdigestyakh
# Processing Record 28 of Set 10 | jaunjelgava
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | nenjiang
# Processing Record 31 of Set 10 | nago
# Processing Record 32 of Set 10 | mogadishu
# Processing Record 33 of Set 10 | kashiwazaki
# Processing Record 34 of Set 10 | xibing
# Processing Record 35 of Set 10 | colonia
# Processing Record 36 of Set 10 | sinjai
# Processing Record 37 of Set 10 | paracuru
# Processing Record 38 of Set 10 | cidade velha
# Processing Record 39 of Set 10 | grand baie
# Processing Record 40 of Set 10 | arkhangel'sk
# Processing Record 41 of Set 10 | castellarano
# Processing Record 42 of Set 10 | sahy
# Processing Record 43 of Set 10 | markovo
# Processing Record 44 of Set 10 | canto do buriti
# Processing Record 45 of Set 10 | pemangkat
# Processing Record 46 of Set 10 | tsarevo
# Processing Record 47 of Set 10 | kirakira
# Processing Record 48 of Set 10 | sokcho
# Processing Record 49 of Set 10 | aioun
# Processing Record 50 of Set 10 | kargil
# Processing Record 1 of Set 11 | fonadhoo
# City not found. Skipping...
# Processing Record 2 of Set 11 | ilanskiy
# Processing Record 3 of Set 11 | yen bai
# Processing Record 4 of Set 11 | bandar-e anzali
# Processing Record 5 of Set 11 | nuuk
# Processing Record 6 of Set 11 | la ronge
# Processing Record 7 of Set 11 | la palma
# Processing Record 8 of Set 11 | hilo
# Processing Record 9 of Set 11 | witu
# Processing Record 10 of Set 11 | zolochiv
# Processing Record 11 of Set 11 | suratgarh
# Processing Record 12 of Set 11 | kununurra
# Processing Record 13 of Set 11 | nar'yan-mar
# Processing Record 14 of Set 11 | myitkyina
# Processing Record 15 of Set 11 | tangalle
# Processing Record 16 of Set 11 | yafran
# Processing Record 17 of Set 11 | al artawiyah
# Processing Record 18 of Set 11 | lethbridge
# Processing Record 19 of Set 11 | undurkhaan
# Processing Record 20 of Set 11 | callaway
# Processing Record 21 of Set 11 | harper
# Processing Record 22 of Set 11 | fort st. john
# Processing Record 23 of Set 11 | ulladulla
# Processing Record 24 of Set 11 | copala
# Processing Record 25 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 26 of Set 11 | ostseebad binz
# Processing Record 27 of Set 11 | tarrafal
# Processing Record 28 of Set 11 | zhuanghe
# Processing Record 29 of Set 11 | fortuna
# Processing Record 30 of Set 11 | sishilichengzi
# City not found. Skipping...
# Processing Record 31 of Set 11 | qamdo
# Processing Record 32 of Set 11 | horsham
# Processing Record 33 of Set 11 | tevriz
# Processing Record 34 of Set 11 | yamada
# Processing Record 35 of Set 11 | rezh
# Processing Record 36 of Set 11 | tofol
# Processing Record 37 of Set 11 | pohrebyshche
# Processing Record 38 of Set 11 | hirado
# Processing Record 39 of Set 11 | afaahiti
# Processing Record 40 of Set 11 | palmerston
# Processing Record 41 of Set 11 | moyynkum
# Processing Record 42 of Set 11 | kushnarenkovo
# Processing Record 43 of Set 11 | sao tome
# Processing Record 44 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 45 of Set 11 | talara
# Processing Record 46 of Set 11 | livingstonia
# Processing Record 47 of Set 11 | buta
# Processing Record 48 of Set 11 | swakopmund
# Processing Record 49 of Set 11 | east london
# Processing Record 50 of Set 11 | manadhoo
# Processing Record 1 of Set 12 | kuanda
# Processing Record 2 of Set 12 | san javier
# Processing Record 3 of Set 12 | relizane
# Processing Record 4 of Set 12 | ijuw
# City not found. Skipping...
# Processing Record 5 of Set 12 | tocopilla
# Processing Record 6 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 7 of Set 12 | korla
# Processing Record 8 of Set 12 | baruun-urt
# Processing Record 9 of Set 12 | al jawf
# Processing Record 10 of Set 12 | fort morgan
# Processing Record 11 of Set 12 | ambodifotatra
# Processing Record 12 of Set 12 | nanning
# Processing Record 13 of Set 12 | kaihua
# Processing Record 14 of Set 12 | uyar
# Processing Record 15 of Set 12 | san roque
# Processing Record 16 of Set 12 | inarajan village
# Processing Record 17 of Set 12 | mpanda
# Processing Record 18 of Set 12 | ulanhot
# Processing Record 19 of Set 12 | dwarka
# Processing Record 20 of Set 12 | argostolion
# Processing Record 21 of Set 12 | el bolson
# Processing Record 22 of Set 12 | puerto baquerizo moreno
# Processing Record 23 of Set 12 | greenville
# Processing Record 24 of Set 12 | magong
# Processing Record 25 of Set 12 | anloga
# Processing Record 26 of Set 12 | lorengau
# Processing Record 27 of Set 12 | mahina
# Processing Record 28 of Set 12 | sinabang
# Processing Record 29 of Set 12 | calca
# Processing Record 30 of Set 12 | ammi moussa
# Processing Record 31 of Set 12 | odacho-oda
# Processing Record 32 of Set 12 | bubaque
# Processing Record 33 of Set 12 | grand falls-windsor
# Processing Record 34 of Set 12 | roosevelt
# Processing Record 35 of Set 12 | salalah
# Processing Record 36 of Set 12 | maceio
# Processing Record 37 of Set 12 | baluntaicun
# City not found. Skipping...
# Processing Record 38 of Set 12 | kayangel
# Processing Record 39 of Set 12 | francisco i. madero
# Processing Record 40 of Set 12 | yuzhno-kurilsk
# Processing Record 41 of Set 12 | vorkuta
# Processing Record 42 of Set 12 | nouadhibou
# Processing Record 43 of Set 12 | black point
# Processing Record 44 of Set 12 | barra do corda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      4.59        77          26
# 1         st. john's  47.5649  -52.7093      9.60        89         100
# 2              sitka  57.0531 -135.3300      6.94        70          75
# 3     preobrazheniye  42.9019  133.9064      3.69        90          99
# 4         rio grande -32.0350  -52.0986     23.06        90         100
#
#    Wind Speed Country        Date
# 0       14.73      TF  05/07/2024
# 1        3.09      CA  05/07/2024
# 2        5.66      US  05/07/2024
# 3        1.85      RU  05/07/2024
# 4        5.15      BR  05/07/2024

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      4.59        77          26
# 1               st. john's  47.5649  -52.7093      9.60        89         100
# 2                    sitka  57.0531 -135.3300      6.94        70          75
# 3           preobrazheniye  42.9019  133.9064      3.69        90          99
# 4               rio grande -32.0350  -52.0986     23.06        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0             14.73      TF  05/07/2024
# 1              3.09      CA  05/07/2024
# 2              5.66      US  05/07/2024
# 3              1.85      RU  05/07/2024
# 4              5.15      BR  05/07/2024

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Max Temp', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude .vs Max Temperature (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Max Temperature (C)"
                 )

# Save the figure
plt.savefig("output_data/Scatter_Lat_vs_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Humidity', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Humidity (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Humidity (%)"
                 )

# Save the figure
plt.savefig("output_data/Scatter_Lat_vs_hum.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Cloudiness', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Cloudiness (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Cloudiness (%)"
                 )

# Save the figure
plt.savefig("output_data/scatter_lat_vs_cld.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Wind Speed', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Wind Speed (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Wind Speed (m/s)"
                 )

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def Lin_Reg_Plt(df, x, y):
    x_values = df[x]
    y_values = df[y]
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    rvalue = round(rvalue, 3)
    
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values, s=60, color='darkcyan', edgecolor='black')
    
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.5, 0.1), xycoords='axes fraction', fontsize=15,color="red", ha='center', va='bottom')

    plt.xlabel('Latitude')
    plt.ylabel(y)
    print("The r-value is: " + str(rvalue))
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
n_hemi_city_data_df = city_data_df.loc[city_data_df['Lat']  >= 0]

# Display sample data
n_hemi_city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            st. john's  47.5649  -52.7093      9.60        89         100
# 2                 sitka  57.0531 -135.3300      6.94        70          75
# 3        preobrazheniye  42.9019  133.9064      3.69        90          99
# 5         haiku-pauwela  20.9219 -156.3051     22.25        79          20
# 6        ribeira grande  38.5167  -28.7000     19.32        94          40
#
#          Wind Speed Country        Date
# City_ID
# 1              3.09      CA  05/07/2024
# 2              5.66      US  05/07/2024
# 3              1.85      RU  05/07/2024
# 5              2.68      US  05/07/2024
# 6              6.71      PT  05/07/2024

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
s_hemi_city_data_df = city_data_df.loc[city_data_df['Lat']  < 0]

# Display sample data
s_hemi_city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      4.59        77          26
# 4               rio grande -32.0350  -52.0986     23.06        90         100
# 8                adamstown -25.0660 -130.1015     21.57        78          45
# 23           atafu village  -8.5421 -172.5159     29.58        77          46
# 25            invercargill -46.4000  168.3500      6.12        89          99
#
#          Wind Speed Country        Date
# City_ID
# 0             14.73      TF  05/07/2024
# 4              5.15      BR  05/07/2024
# 8              5.01      PN  05/07/2024
# 23             5.18      TK  05/07/2024
# 25             2.24      NZ  05/07/2024

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat' ,'Max Temp')
# Out:
# The r-value is: -0.836

# %%
# Linear regression on Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat' ,'Max Temp')
# Out:
# The r-value is: 0.778

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Temperature.  The data points show that Temperature rises as the Latitude gets closer to 0 (equator).  The R-values show quantitatively that there is a high correlation between Temperature and Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Humidity')
# Out:
# The r-value is: 0.124

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Humidity')
# Out:
# The r-value is: -0.072

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Humidity. There are more data points for Humidity above 50 than below and looks to be evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Humidity and Latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.062

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.122

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Cloudiness. The highest concentration of Cloudiness data is at 0 and 100 and looks evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Cloudiness and Latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Wind Speed')
# Out:
# The r-value is: 0.138

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Wind Speed')
# Out:
# The r-value is: 0.0

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Wind Speed and Humidity. The volume of data points for Wind Speed decreases above 15 and looks to be evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Wind Speed and Latitude.
