# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 619

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        timestamp = city_weather['dt']
        # Convert date format from Unix to UTC
        utc_date_struct = time.gmtime(timestamp)
        city_date = time.strftime('%m/%d/%Y', utc_date_struct)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carrick-on-suir
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | invercargill
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | bertioga
# Processing Record 7 of Set 1 | fort-shevchenko
# Processing Record 8 of Set 1 | shimoda
# Processing Record 9 of Set 1 | bilibino
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | malango
# Processing Record 12 of Set 1 | weno
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | puerto natales
# Processing Record 16 of Set 1 | qaqortoq
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | paita
# Processing Record 19 of Set 1 | aras-asan
# Processing Record 20 of Set 1 | isafjordur
# Processing Record 21 of Set 1 | mount pearl
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | maues
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | haiku-pauwela
# Processing Record 26 of Set 1 | afaahiti
# Processing Record 27 of Set 1 | hammerfest
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | yuktae-dong
# Processing Record 30 of Set 1 | saipan
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | huocheng
# City not found. Skipping...
# Processing Record 33 of Set 1 | pangody
# Processing Record 34 of Set 1 | mili
# Processing Record 35 of Set 1 | champerico
# Processing Record 36 of Set 1 | chibougamau
# Processing Record 37 of Set 1 | matoury
# Processing Record 38 of Set 1 | makokou
# Processing Record 39 of Set 1 | margaret river
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | vadso
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | novopskov
# Processing Record 46 of Set 1 | susuman
# Processing Record 47 of Set 1 | ribeira brava
# Processing Record 48 of Set 1 | san antonio de pale
# Processing Record 49 of Set 1 | caleta de carquin
# Processing Record 50 of Set 1 | hirara
# Processing Record 1 of Set 2 | papatowai
# Processing Record 2 of Set 2 | mil'kovo
# Processing Record 3 of Set 2 | utrik
# Processing Record 4 of Set 2 | dryden
# Processing Record 5 of Set 2 | jalai nur
# Processing Record 6 of Set 2 | wailua homesteads
# Processing Record 7 of Set 2 | bargara
# City not found. Skipping...
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | touros
# Processing Record 10 of Set 2 | yuzhno-kurilsk
# Processing Record 11 of Set 2 | sheksna
# Processing Record 12 of Set 2 | setti fatma
# City not found. Skipping...
# Processing Record 13 of Set 2 | murakami
# Processing Record 14 of Set 2 | jining
# Processing Record 15 of Set 2 | laojunmiao
# Processing Record 16 of Set 2 | queenstown
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | champua
# Processing Record 19 of Set 2 | kingston
# Processing Record 20 of Set 2 | kununurra
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | laukaa
# Processing Record 23 of Set 2 | kismayo
# Processing Record 24 of Set 2 | manaus
# Processing Record 25 of Set 2 | klyuchi
# Processing Record 26 of Set 2 | puerto leguizamo
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | keflavik
# Processing Record 30 of Set 2 | rio claro
# Processing Record 31 of Set 2 | san matias
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | bamboo flat
# Processing Record 34 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 35 of Set 2 | acarau
# Processing Record 36 of Set 2 | plastun
# Processing Record 37 of Set 2 | key west
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | petrovsk
# Processing Record 40 of Set 2 | ta`u
# Processing Record 41 of Set 2 | morondava
# Processing Record 42 of Set 2 | mata-utu
# Processing Record 43 of Set 2 | magadan
# Processing Record 44 of Set 2 | el calafate
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | coahuayana de hidalgo
# Processing Record 47 of Set 2 | turochak
# Processing Record 48 of Set 2 | anadyr
# Processing Record 49 of Set 2 | castillos
# Processing Record 50 of Set 2 | chul'man
# Processing Record 1 of Set 3 | blackmans bay
# Processing Record 2 of Set 3 | uliastay
# Processing Record 3 of Set 3 | cable beach
# City not found. Skipping...
# Processing Record 4 of Set 3 | el-tor
# Processing Record 5 of Set 3 | vila do maio
# Processing Record 6 of Set 3 | bay city
# Processing Record 7 of Set 3 | firmat
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | korla
# Processing Record 10 of Set 3 | illushi
# Processing Record 11 of Set 3 | ende
# Processing Record 12 of Set 3 | jayapura
# Processing Record 13 of Set 3 | klaksvik
# Processing Record 14 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | lihue
# Processing Record 17 of Set 3 | hotan
# Processing Record 18 of Set 3 | olonkinbyen
# Processing Record 19 of Set 3 | aral
# Processing Record 20 of Set 3 | port douglas
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | paradip garh
# Processing Record 23 of Set 3 | badger
# Processing Record 24 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 3 | globe
# City not found. Skipping...
# Processing Record 26 of Set 3 | teknaf
# Processing Record 27 of Set 3 | ubinskoye
# Processing Record 28 of Set 3 | ciudad pemex
# Processing Record 29 of Set 3 | san martin
# Processing Record 30 of Set 3 | asubulaq
# Processing Record 31 of Set 3 | murghob
# Processing Record 32 of Set 3 | boa vista
# Processing Record 33 of Set 3 | menaka
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | taroa
# Processing Record 36 of Set 3 | alofi
# Processing Record 37 of Set 3 | praia da vitoria
# Processing Record 38 of Set 3 | udachny
# Processing Record 39 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 40 of Set 3 | rundu
# Processing Record 41 of Set 3 | sandnessjoen
# Processing Record 42 of Set 3 | zouerate
# Processing Record 43 of Set 3 | grand gaube
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | hawaiian paradise park
# Processing Record 46 of Set 3 | alice springs
# Processing Record 47 of Set 3 | kuala belait
# Processing Record 48 of Set 3 | polyarnyy
# Processing Record 49 of Set 3 | canutama
# Processing Record 50 of Set 3 | namsos
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | nuku'alofa
# Processing Record 3 of Set 4 | ushuaia
# Processing Record 4 of Set 4 | nova sintra
# Processing Record 5 of Set 4 | cranbrook
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | gornozavodsk
# Processing Record 8 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 4 | emerald
# Processing Record 10 of Set 4 | amahai
# Processing Record 11 of Set 4 | babor - ville
# Processing Record 12 of Set 4 | egilsstadir
# Processing Record 13 of Set 4 | atafu village
# Processing Record 14 of Set 4 | zhezqazghan
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | genhe
# Processing Record 17 of Set 4 | west island
# Processing Record 18 of Set 4 | fengxiang
# Processing Record 19 of Set 4 | kavaratti
# Processing Record 20 of Set 4 | am djarass
# City not found. Skipping...
# Processing Record 21 of Set 4 | kenora
# Processing Record 22 of Set 4 | tarauaca
# Processing Record 23 of Set 4 | aoulef
# Processing Record 24 of Set 4 | whitehorse
# Processing Record 25 of Set 4 | port mathurin
# Processing Record 26 of Set 4 | okanagan
# Processing Record 27 of Set 4 | makurazaki
# Processing Record 28 of Set 4 | zapata
# Processing Record 29 of Set 4 | bonga
# Processing Record 30 of Set 4 | stanley
# Processing Record 31 of Set 4 | salem
# Processing Record 32 of Set 4 | mammoth lakes
# Processing Record 33 of Set 4 | luanda
# Processing Record 34 of Set 4 | yarmouth
# Processing Record 35 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 36 of Set 4 | bandarbeyla
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | tazovsky
# Processing Record 39 of Set 4 | puerto baquerizo moreno
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | smithers
# Processing Record 42 of Set 4 | pionerskiy
# Processing Record 43 of Set 4 | kidal
# Processing Record 44 of Set 4 | fort st. john
# Processing Record 45 of Set 4 | constantia
# Processing Record 46 of Set 4 | igarka
# Processing Record 47 of Set 4 | rongelap
# Processing Record 48 of Set 4 | avarua
# Processing Record 49 of Set 4 | ararat
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | chonchi
# Processing Record 2 of Set 5 | itamaraca
# Processing Record 3 of Set 5 | codrington
# Processing Record 4 of Set 5 | taos
# Processing Record 5 of Set 5 | alo
# Processing Record 6 of Set 5 | carrizo springs
# Processing Record 7 of Set 5 | tura
# Processing Record 8 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 9 of Set 5 | baiao
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | vilyuchinsk
# Processing Record 12 of Set 5 | tsiombe
# Processing Record 13 of Set 5 | arteche
# Processing Record 14 of Set 5 | cidade velha
# Processing Record 15 of Set 5 | port hedland
# Processing Record 16 of Set 5 | mermoz boabab
# Processing Record 17 of Set 5 | illizi
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | bonthe
# Processing Record 20 of Set 5 | peruibe
# Processing Record 21 of Set 5 | pudasjarvi
# Processing Record 22 of Set 5 | uturoa
# Processing Record 23 of Set 5 | lata
# Processing Record 24 of Set 5 | marsa alam
# Processing Record 25 of Set 5 | parvatipuram
# Processing Record 26 of Set 5 | maxixe
# Processing Record 27 of Set 5 | shingu
# Processing Record 28 of Set 5 | fraijanes
# Processing Record 29 of Set 5 | zarghun shahr
# Processing Record 30 of Set 5 | st. john's
# Processing Record 31 of Set 5 | maracaju
# Processing Record 32 of Set 5 | twon-brass
# Processing Record 33 of Set 5 | nantai
# Processing Record 34 of Set 5 | langepas
# Processing Record 35 of Set 5 | bealanana
# Processing Record 36 of Set 5 | ternate
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | tosontsengel
# Processing Record 40 of Set 5 | nogliki
# Processing Record 41 of Set 5 | muisne
# Processing Record 42 of Set 5 | monticello
# Processing Record 43 of Set 5 | el alto
# Processing Record 44 of Set 5 | meulaboh
# Processing Record 45 of Set 5 | sanya
# Processing Record 46 of Set 5 | midvagur
# Processing Record 47 of Set 5 | sitka
# Processing Record 48 of Set 5 | aasiaat
# Processing Record 49 of Set 5 | ankazoabo
# Processing Record 50 of Set 5 | quellon
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | bridgewater
# Processing Record 3 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 6 | sittwe
# Processing Record 5 of Set 6 | lodwar
# Processing Record 6 of Set 6 | soio
# Processing Record 7 of Set 6 | kapenguria
# Processing Record 8 of Set 6 | debark'
# Processing Record 9 of Set 6 | fortaleza
# Processing Record 10 of Set 6 | brisas de zicatela
# Processing Record 11 of Set 6 | labuan lombok
# City not found. Skipping...
# Processing Record 12 of Set 6 | magistral'nyy
# Processing Record 13 of Set 6 | zara
# Processing Record 14 of Set 6 | khanty-mansiysk
# Processing Record 15 of Set 6 | sola
# Processing Record 16 of Set 6 | neklyudovo
# Processing Record 17 of Set 6 | ayr
# Processing Record 18 of Set 6 | tyuratam
# Processing Record 19 of Set 6 | dunedin
# Processing Record 20 of Set 6 | gamba
# Processing Record 21 of Set 6 | kudahuvadhoo
# Processing Record 22 of Set 6 | polatli
# Processing Record 23 of Set 6 | yarkovo
# Processing Record 24 of Set 6 | gadzhiyevo
# Processing Record 25 of Set 6 | viransehir
# Processing Record 26 of Set 6 | brookings
# Processing Record 27 of Set 6 | laguna
# Processing Record 28 of Set 6 | isla vista
# Processing Record 29 of Set 6 | howard springs
# Processing Record 30 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 31 of Set 6 | ar ruways
# Processing Record 32 of Set 6 | iquique
# Processing Record 33 of Set 6 | charters towers
# Processing Record 34 of Set 6 | boguchany
# Processing Record 35 of Set 6 | khilok
# Processing Record 36 of Set 6 | cidreira
# Processing Record 37 of Set 6 | greymouth
# Processing Record 38 of Set 6 | puerto san jose
# Processing Record 39 of Set 6 | siwa oasis
# Processing Record 40 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 6 | kailua-kona
# Processing Record 42 of Set 6 | lautoka
# Processing Record 43 of Set 6 | nadym
# Processing Record 44 of Set 6 | nairn
# Processing Record 45 of Set 6 | margate
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | krotovka
# Processing Record 48 of Set 6 | kovernino
# Processing Record 49 of Set 6 | portland
# Processing Record 50 of Set 6 | saldanha
# Processing Record 1 of Set 7 | las matas de santa cruz
# Processing Record 2 of Set 7 | velikiye luki
# Processing Record 3 of Set 7 | kerikeri
# Processing Record 4 of Set 7 | mejit
# Processing Record 5 of Set 7 | wynyard
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | namibe
# Processing Record 8 of Set 7 | plouay
# Processing Record 9 of Set 7 | oualidia
# City not found. Skipping...
# Processing Record 10 of Set 7 | porbandar
# Processing Record 11 of Set 7 | buka
# Processing Record 12 of Set 7 | bosobolo
# Processing Record 13 of Set 7 | cururupu
# Processing Record 14 of Set 7 | nueva villa de padilla
# Processing Record 15 of Set 7 | saiha
# Processing Record 16 of Set 7 | shancheng
# Processing Record 17 of Set 7 | opuwo
# Processing Record 18 of Set 7 | kapa'a
# Processing Record 19 of Set 7 | at taj
# Processing Record 20 of Set 7 | hellin
# Processing Record 21 of Set 7 | berezovyy
# Processing Record 22 of Set 7 | fale old settlement
# Processing Record 23 of Set 7 | van wert
# Processing Record 24 of Set 7 | cartaxo
# Processing Record 25 of Set 7 | kenai
# Processing Record 26 of Set 7 | hinton
# Processing Record 27 of Set 7 | inhambane
# Processing Record 28 of Set 7 | tazacorte
# Processing Record 29 of Set 7 | iskateley
# Processing Record 30 of Set 7 | mhamid
# Processing Record 31 of Set 7 | safi
# Processing Record 32 of Set 7 | novokazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 7 | tindouf
# Processing Record 34 of Set 7 | concepcion de la sierra
# Processing Record 35 of Set 7 | xining
# Processing Record 36 of Set 7 | sinop
# Processing Record 37 of Set 7 | kristiansund
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | mel'nikovo
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | milici
# Processing Record 42 of Set 7 | zhetybay
# City not found. Skipping...
# Processing Record 43 of Set 7 | nabire
# Processing Record 44 of Set 7 | lodja
# Processing Record 45 of Set 7 | las khorey
# Processing Record 46 of Set 7 | sinabang
# Processing Record 47 of Set 7 | veraval
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | elmendorf air force base
# City not found. Skipping...
# Processing Record 50 of Set 7 | qarazhal
# Processing Record 1 of Set 8 | beyneu
# Processing Record 2 of Set 8 | xiazhuang
# Processing Record 3 of Set 8 | dudinka
# Processing Record 4 of Set 8 | kormilovka
# Processing Record 5 of Set 8 | mahanoro
# Processing Record 6 of Set 8 | huaicheng
# Processing Record 7 of Set 8 | warrnambool
# Processing Record 8 of Set 8 | kavieng
# Processing Record 9 of Set 8 | soure
# Processing Record 10 of Set 8 | vytegra
# Processing Record 11 of Set 8 | ballina
# Processing Record 12 of Set 8 | sungai penuh
# Processing Record 13 of Set 8 | jumla
# Processing Record 14 of Set 8 | khamis mushait
# Processing Record 15 of Set 8 | aioun
# Processing Record 16 of Set 8 | tibanbang
# Processing Record 17 of Set 8 | kolonia
# Processing Record 18 of Set 8 | podporozh'ye
# Processing Record 19 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 20 of Set 8 | behshahr
# Processing Record 21 of Set 8 | novodvinsk
# Processing Record 22 of Set 8 | laminusa
# Processing Record 23 of Set 8 | gizo
# Processing Record 24 of Set 8 | lewistown
# Processing Record 25 of Set 8 | winejok
# City not found. Skipping...
# Processing Record 26 of Set 8 | naberezhnyye chelny
# Processing Record 27 of Set 8 | gordonvale
# Processing Record 28 of Set 8 | fortuna
# Processing Record 29 of Set 8 | mabaruma
# Processing Record 30 of Set 8 | sugarcreek
# Processing Record 31 of Set 8 | saint marys
# Processing Record 32 of Set 8 | rabaul
# Processing Record 33 of Set 8 | tougan
# Processing Record 34 of Set 8 | aleg
# Processing Record 35 of Set 8 | happy valley-goose bay
# Processing Record 36 of Set 8 | nybro
# Processing Record 37 of Set 8 | kampene
# Processing Record 38 of Set 8 | nikel
# Processing Record 39 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 40 of Set 8 | ust-nera
# Processing Record 41 of Set 8 | luderitz
# Processing Record 42 of Set 8 | tofol
# Processing Record 43 of Set 8 | letlhakane
# Processing Record 44 of Set 8 | paris
# Processing Record 45 of Set 8 | chengde
# Processing Record 46 of Set 8 | enewetak
# Processing Record 47 of Set 8 | krasnyy oktyabr'
# Processing Record 48 of Set 8 | selkirk
# Processing Record 49 of Set 8 | mount gambier
# Processing Record 50 of Set 8 | revda
# Processing Record 1 of Set 9 | timbuktu
# Processing Record 2 of Set 9 | ryotsu-minato
# Processing Record 3 of Set 9 | prado
# Processing Record 4 of Set 9 | sorong
# Processing Record 5 of Set 9 | papao
# Processing Record 6 of Set 9 | lakatoro
# Processing Record 7 of Set 9 | belmonte
# Processing Record 8 of Set 9 | hastings
# Processing Record 9 of Set 9 | taco pozo
# Processing Record 10 of Set 9 | la passe
# Processing Record 11 of Set 9 | grimmen
# Processing Record 12 of Set 9 | vorgashor
# Processing Record 13 of Set 9 | mthatha
# Processing Record 14 of Set 9 | vyazemskiy
# Processing Record 15 of Set 9 | tulagi
# Processing Record 16 of Set 9 | meadow lake
# Processing Record 17 of Set 9 | nar'yan-mar
# Processing Record 18 of Set 9 | cacule
# Processing Record 19 of Set 9 | kapuskasing
# Processing Record 20 of Set 9 | puerto quijarro
# Processing Record 21 of Set 9 | tokar
# Processing Record 22 of Set 9 | guasdualito
# Processing Record 23 of Set 9 | hadibu
# Processing Record 24 of Set 9 | mar del plata
# Processing Record 25 of Set 9 | westport
# Processing Record 26 of Set 9 | ad dilam
# Processing Record 27 of Set 9 | labrador city
# Processing Record 28 of Set 9 | merizo village
# Processing Record 29 of Set 9 | marand
# Processing Record 30 of Set 9 | kiunga
# Processing Record 31 of Set 9 | necochea
# Processing Record 32 of Set 9 | shenjiamen
# Processing Record 33 of Set 9 | chui
# Processing Record 34 of Set 9 | abalak
# Processing Record 35 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 36 of Set 9 | xilin hot
# Processing Record 37 of Set 9 | west bay
# Processing Record 38 of Set 9 | kalamnuri
# Processing Record 39 of Set 9 | black point
# Processing Record 40 of Set 9 | sai buri
# Processing Record 41 of Set 9 | veszto
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | al 'ubaydiyah
# City not found. Skipping...
# Processing Record 44 of Set 9 | lazaro cardenas
# Processing Record 45 of Set 9 | la serena
# Processing Record 46 of Set 9 | upington
# Processing Record 47 of Set 9 | ocean shores
# Processing Record 48 of Set 9 | ulladulla
# Processing Record 49 of Set 9 | ourem
# Processing Record 50 of Set 9 | yung shue wan
# Processing Record 1 of Set 10 | maranding
# Processing Record 2 of Set 10 | san juanito
# Processing Record 3 of Set 10 | burumburum
# Processing Record 4 of Set 10 | ardestan
# Processing Record 5 of Set 10 | vilyuysk
# Processing Record 6 of Set 10 | sao paulo de olivenca
# Processing Record 7 of Set 10 | newton
# Processing Record 8 of Set 10 | palu
# Processing Record 9 of Set 10 | awjilah
# Processing Record 10 of Set 10 | santiago de cuba
# Processing Record 11 of Set 10 | pandan
# Processing Record 12 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 13 of Set 10 | oulainen
# Processing Record 14 of Set 10 | andergrove
# Processing Record 15 of Set 10 | yaren
# Processing Record 16 of Set 10 | mukalla
# Processing Record 17 of Set 10 | sirpur
# Processing Record 18 of Set 10 | saliste
# Processing Record 19 of Set 10 | kirakira
# Processing Record 20 of Set 10 | vila franca do campo
# Processing Record 21 of Set 10 | ijuw
# City not found. Skipping...
# Processing Record 22 of Set 10 | ngaoundere
# Processing Record 23 of Set 10 | metlili chaamba
# Processing Record 24 of Set 10 | lang son
# Processing Record 25 of Set 10 | tolanaro
# Processing Record 26 of Set 10 | schweizer-reneke
# Processing Record 27 of Set 10 | mawu
# Processing Record 28 of Set 10 | los alamos
# Processing Record 29 of Set 10 | zabol
# Processing Record 30 of Set 10 | biryusinsk
# Processing Record 31 of Set 10 | vershino-darasunskiy
# Processing Record 32 of Set 10 | puerto el triunfo
# Processing Record 33 of Set 10 | nemuro
# Processing Record 34 of Set 10 | pontes e lacerda
# Processing Record 35 of Set 10 | karratha
# Processing Record 36 of Set 10 | bengkulu
# Processing Record 37 of Set 10 | mokshan
# Processing Record 38 of Set 10 | zheleznodorozhnyy
# Processing Record 39 of Set 10 | sahatavy
# City not found. Skipping...
# Processing Record 40 of Set 10 | kuta
# Processing Record 41 of Set 10 | yemva
# Processing Record 42 of Set 10 | argo
# Processing Record 43 of Set 10 | anahuac
# Processing Record 44 of Set 10 | raymondville
# Processing Record 45 of Set 10 | al ghayzah
# Processing Record 46 of Set 10 | edd
# Processing Record 47 of Set 10 | zhmerynka
# Processing Record 48 of Set 10 | leeton
# Processing Record 49 of Set 10 | urangan
# Processing Record 50 of Set 10 | marsh harbour
# Processing Record 1 of Set 11 | niafunke
# Processing Record 2 of Set 11 | toro
# Processing Record 3 of Set 11 | ndago
# Processing Record 4 of Set 11 | dahlonega
# Processing Record 5 of Set 11 | tabou
# Processing Record 6 of Set 11 | okhotsk
# Processing Record 7 of Set 11 | usol'ye-sibirskoye
# Processing Record 8 of Set 11 | osinovo
# Processing Record 9 of Set 11 | zhongshu
# Processing Record 10 of Set 11 | blantyre
# Processing Record 11 of Set 11 | tonghae
# Processing Record 12 of Set 11 | barroso
# Processing Record 13 of Set 11 | mongo
# Processing Record 14 of Set 11 | la punta
# Processing Record 15 of Set 11 | rudnichnyy
# Processing Record 16 of Set 11 | raduzhny
# Processing Record 17 of Set 11 | miri
# Processing Record 18 of Set 11 | tumpat
# Processing Record 19 of Set 11 | sur
# Processing Record 20 of Set 11 | oruro
# Processing Record 21 of Set 11 | dalandzadgad
# Processing Record 22 of Set 11 | aleksandrov gay
# Processing Record 23 of Set 11 | sainte-anne-des-monts
# Processing Record 24 of Set 11 | koster
# Processing Record 25 of Set 11 | artvin
# Processing Record 26 of Set 11 | seminole
# Processing Record 27 of Set 11 | san carlos
# Processing Record 28 of Set 11 | tynda
# Processing Record 29 of Set 11 | lorengau
# Processing Record 30 of Set 11 | maubara
# City not found. Skipping...
# Processing Record 31 of Set 11 | la ronge
# Processing Record 32 of Set 11 | oltinko'l
# Processing Record 33 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 34 of Set 11 | strezhevoy
# Processing Record 35 of Set 11 | lensk
# Processing Record 36 of Set 11 | vallenar
# Processing Record 37 of Set 11 | nahiyat ash shinafiyah
# Processing Record 38 of Set 11 | mount isa
# Processing Record 39 of Set 11 | kone
# Processing Record 40 of Set 11 | bunia
# Processing Record 41 of Set 11 | rio pardo de minas
# Processing Record 42 of Set 11 | al jawf
# Processing Record 43 of Set 11 | nouadhibou
# Processing Record 44 of Set 11 | cianorte
# Processing Record 45 of Set 11 | thatta
# Processing Record 46 of Set 11 | azogues
# Processing Record 47 of Set 11 | torteval
# City not found. Skipping...
# Processing Record 48 of Set 11 | misliyah
# Processing Record 49 of Set 11 | along
# Processing Record 50 of Set 11 | plettenberg bay
# Processing Record 1 of Set 12 | lucena
# Processing Record 2 of Set 12 | fisterra
# Processing Record 3 of Set 12 | tual
# Processing Record 4 of Set 12 | bardai
# Processing Record 5 of Set 12 | hobyo
# Processing Record 6 of Set 12 | suksun
# Processing Record 7 of Set 12 | fort bragg
# Processing Record 8 of Set 12 | ouellah
# City not found. Skipping...
# Processing Record 9 of Set 12 | ormara
# Processing Record 10 of Set 12 | diamantino
# Processing Record 11 of Set 12 | shache
# Processing Record 12 of Set 12 | saint-gaudens
# Processing Record 13 of Set 12 | padang
# Processing Record 14 of Set 12 | mooloolaba
# Processing Record 15 of Set 12 | sanctuary point
# Processing Record 16 of Set 12 | ulsteinvik
# Processing Record 17 of Set 12 | buenaventura
# Processing Record 18 of Set 12 | montefrio
# Processing Record 19 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 20 of Set 12 | mangrol
# Processing Record 21 of Set 12 | gallup
# Processing Record 22 of Set 12 | colac
# Processing Record 23 of Set 12 | zakynthos
# Processing Record 24 of Set 12 | arraial do cabo
# Processing Record 25 of Set 12 | seaside
# Processing Record 26 of Set 12 | roma
# Processing Record 27 of Set 12 | conduaga
# Processing Record 28 of Set 12 | rawson
# Processing Record 29 of Set 12 | lerwick
# Processing Record 30 of Set 12 | masterton
# Processing Record 31 of Set 12 | barra de santo antonio
# Processing Record 32 of Set 12 | isangel
# Processing Record 33 of Set 12 | yinchuan
# Processing Record 34 of Set 12 | kirensk
# Processing Record 35 of Set 12 | lys'va
# Processing Record 36 of Set 12 | jamaame
# Processing Record 37 of Set 12 | plainville
# Processing Record 38 of Set 12 | nishinoomote
# Processing Record 39 of Set 12 | tralee
# Processing Record 40 of Set 12 | broome
# Processing Record 41 of Set 12 | corozal
# Processing Record 42 of Set 12 | chillicothe
# Processing Record 43 of Set 12 | bismarck
# Processing Record 44 of Set 12 | glazov
# Processing Record 45 of Set 12 | erenhot
# Processing Record 46 of Set 12 | toliara
# Processing Record 47 of Set 12 | zuera
# Processing Record 48 of Set 12 | aykhal
# Processing Record 49 of Set 12 | malakal
# Processing Record 50 of Set 12 | velasco ibarra
# Processing Record 1 of Set 13 | douglas
# Processing Record 2 of Set 13 | taro
# Processing Record 3 of Set 13 | lashio
# Processing Record 4 of Set 13 | adh dhibiyah
# City not found. Skipping...
# Processing Record 5 of Set 13 | joshimath
# Processing Record 6 of Set 13 | nuuk
# Processing Record 7 of Set 13 | bich'vinta
# Processing Record 8 of Set 13 | isola di capo rizzuto
# Processing Record 9 of Set 13 | kalaleh
# Processing Record 10 of Set 13 | port saint john's
# Processing Record 11 of Set 13 | ketchikan
# Processing Record 12 of Set 13 | grants
# Processing Record 13 of Set 13 | lembar
# City not found. Skipping...
# Processing Record 14 of Set 13 | taltal
# Processing Record 15 of Set 13 | mamuju
# Processing Record 16 of Set 13 | yeed
# Processing Record 17 of Set 13 | north tonawanda
# Processing Record 18 of Set 13 | macaubas
# Processing Record 19 of Set 13 | formosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  carrick-on-suir  52.3492   -7.4131     16.47        74          94
# 1     longyearbyen  78.2186   15.6401      0.91        75          75
# 2     invercargill -46.4000  168.3500      6.12        90          96
# 3         waitangi -43.9535 -176.5597      9.63        55          22
# 4           albany  42.6001  -73.9662     19.82        50           0
#
#    Wind Speed Country        Date
# 0        2.22      IE  05/07/2024
# 1        1.54      SJ  05/07/2024
# 2        2.24      NZ  05/07/2024
# 3        3.48      NZ  05/07/2024
# 4        0.89      US  05/07/2024

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        carrick-on-suir  52.3492   -7.4131     16.47        74          94
# 1           longyearbyen  78.2186   15.6401      0.91        75          75
# 2           invercargill -46.4000  168.3500      6.12        90          96
# 3               waitangi -43.9535 -176.5597      9.63        55          22
# 4                 albany  42.6001  -73.9662     19.82        50           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.22      IE  05/07/2024
# 1              1.54      SJ  05/07/2024
# 2              2.24      NZ  05/07/2024
# 3              3.48      NZ  05/07/2024
# 4              0.89      US  05/07/2024

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Max Temp', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude .vs Max Temperature (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Max Temperature (C)"
                 )

# Save the figure
plt.savefig("output_data/Scatter_Lat_vs_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Humidity', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Humidity (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Humidity (%)"
                 )

# Save the figure
plt.savefig("output_data/Scatter_Lat_vs_hum.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Cloudiness', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Cloudiness (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Cloudiness (%)"
                 )

# Save the figure
plt.savefig("output_data/scatter_lat_vs_cld.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Wind Speed', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Wind Speed (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Wind Speed (m/s)"
                 )

# Save the figure
plt.savefig("output_data/scatter_lat_vs_wnd.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def Lin_Reg_Plt(df, x, y):
    x_values = df[x]
    y_values = df[y]
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    rvalue = round(rvalue, 3)
    
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values, s=60, color='darkcyan', edgecolor='black')
    
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.5, 0.1), xycoords='axes fraction', fontsize=15,color="red", ha='center', va='bottom')

    plt.xlabel('Latitude')
    plt.ylabel(y)
    print("The r-value is: " + str(rvalue))
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
n_hemi_city_data_df = city_data_df.loc[city_data_df['Lat']  >= 0]

# Display sample data
n_hemi_city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        carrick-on-suir  52.3492   -7.4131     16.47        74          94
# 1           longyearbyen  78.2186   15.6401      0.91        75          75
# 4                 albany  42.6001  -73.9662     19.82        50           0
# 6        fort-shevchenko  44.5086   50.2630     13.19        94         100
# 7                shimoda  34.6667  138.9500     18.39        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.22      IE  05/07/2024
# 1              1.54      SJ  05/07/2024
# 4              0.89      US  05/07/2024
# 6              9.43      KZ  05/07/2024
# 7              4.17      JP  05/07/2024

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
s_hemi_city_data_df = city_data_df.loc[city_data_df['Lat']  < 0]

# Display sample data
s_hemi_city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             invercargill -46.4000  168.3500      6.12        90          96
# 3                 waitangi -43.9535 -176.5597      9.63        55          22
# 5                 bertioga -23.8544  -46.1386     32.00        51           0
# 9        port-aux-francais -49.3500   70.2167      4.44        77          23
# 10                 malango  -2.9627  119.9001     19.93        99         100
#
#          Wind Speed Country        Date
# City_ID
# 2              2.24      NZ  05/07/2024
# 3              3.48      NZ  05/07/2024
# 5              1.03      BR  05/07/2024
# 9             15.17      TF  05/07/2024
# 10             0.75      ID  05/07/2024

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat' ,'Max Temp')
# Out:
# The r-value is: -0.845

# %%
# Linear regression on Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat' ,'Max Temp')
# Out:
# The r-value is: 0.738

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Temperature.  The data points show that Temperature rises as the Latitude gets closer to 0 (equator).  The R-values show quantitatively that there is a high correlation between Temperature and Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Humidity')
# Out:
# The r-value is: 0.115

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Humidity')
# Out:
# The r-value is: 0.015

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Humidity. There are more data points for Humidity above 50 than below and looks to be evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Humidity and Latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.108

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.286

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Cloudiness. The highest concentration of Cloudiness data is at 0 and 100 and looks evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Cloudiness and Latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Wind Speed')
# Out:
# The r-value is: 0.09

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Wind Speed')
# Out:
# The r-value is: -0.095

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Wind Speed and Humidity. The volume of data points for Wind Speed decreases above 15 and looks to be evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Wind Speed and Latitude.
