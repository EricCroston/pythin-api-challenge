# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        timestamp = city_weather['dt']
        # Convert date format from Unix to UTC
        utc_date_struct = time.gmtime(timestamp)
        city_date = time.strftime('%m/%d/%Y', utc_date_struct)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | dakhla
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | taybad
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | papatowai
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | senanga
# Processing Record 10 of Set 1 | domoni
# Processing Record 11 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 12 of Set 1 | cabedelo
# Processing Record 13 of Set 1 | susuman
# Processing Record 14 of Set 1 | taro
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | klyuchi
# Processing Record 17 of Set 1 | wendouree
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | lihue
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | kapuskasing
# Processing Record 22 of Set 1 | ouellah
# City not found. Skipping...
# Processing Record 23 of Set 1 | bikenibeu village
# Processing Record 24 of Set 1 | ta`u
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | margaret river
# Processing Record 27 of Set 1 | isafjordur
# Processing Record 28 of Set 1 | ghardaia
# Processing Record 29 of Set 1 | poso
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | koksan
# Processing Record 32 of Set 1 | waitangi
# Processing Record 33 of Set 1 | tofol
# Processing Record 34 of Set 1 | sishilichengzi
# City not found. Skipping...
# Processing Record 35 of Set 1 | naze
# Processing Record 36 of Set 1 | saipan
# Processing Record 37 of Set 1 | freetown
# Processing Record 38 of Set 1 | stanley
# Processing Record 39 of Set 1 | vorgashor
# Processing Record 40 of Set 1 | vanimo
# Processing Record 41 of Set 1 | bilibino
# Processing Record 42 of Set 1 | kon tum
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | el hajeb
# Processing Record 46 of Set 1 | newman
# Processing Record 47 of Set 1 | geraldton
# Processing Record 48 of Set 1 | gudalur
# Processing Record 49 of Set 1 | colonia
# Processing Record 50 of Set 1 | utrik
# Processing Record 1 of Set 2 | richards bay
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 4 of Set 2 | koch bihar
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | tinajo
# Processing Record 8 of Set 2 | yung shue wan
# Processing Record 9 of Set 2 | brisas de zicatela
# Processing Record 10 of Set 2 | illizi
# Processing Record 11 of Set 2 | nar'yan-mar
# Processing Record 12 of Set 2 | westport
# Processing Record 13 of Set 2 | jambi city
# Processing Record 14 of Set 2 | remire-montjoly
# Processing Record 15 of Set 2 | kuusamo
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | kintinku
# Processing Record 18 of Set 2 | college
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | invercargill
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | burao
# Processing Record 23 of Set 2 | constantia
# Processing Record 24 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 2 | tezu
# Processing Record 26 of Set 2 | nova vicosa
# Processing Record 27 of Set 2 | weno
# Processing Record 28 of Set 2 | arafat
# Processing Record 29 of Set 2 | rio grande
# Processing Record 30 of Set 2 | arpacay
# Processing Record 31 of Set 2 | olonkinbyen
# Processing Record 32 of Set 2 | antigonish
# Processing Record 33 of Set 2 | udi
# Processing Record 34 of Set 2 | whangarei
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | barra de santo antonio
# Processing Record 37 of Set 2 | cadale
# Processing Record 38 of Set 2 | visakhapatnam
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | lerwick
# Processing Record 41 of Set 2 | vares
# Processing Record 42 of Set 2 | tazacorte
# Processing Record 43 of Set 2 | st. john's
# Processing Record 44 of Set 2 | mossel bay
# Processing Record 45 of Set 2 | greymouth
# Processing Record 46 of Set 2 | tura
# Processing Record 47 of Set 2 | basi
# Processing Record 48 of Set 2 | kavaratti
# Processing Record 49 of Set 2 | port douglas
# Processing Record 50 of Set 2 | fort bragg
# Processing Record 1 of Set 3 | whiteville
# Processing Record 2 of Set 3 | kismayo
# Processing Record 3 of Set 3 | nuuk
# Processing Record 4 of Set 3 | miguel ahumada
# Processing Record 5 of Set 3 | whakatane
# Processing Record 6 of Set 3 | tolanaro
# Processing Record 7 of Set 3 | port mathurin
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | qaqortoq
# Processing Record 10 of Set 3 | selfoss
# Processing Record 11 of Set 3 | at-bashi
# Processing Record 12 of Set 3 | palmer
# Processing Record 13 of Set 3 | hawaiian paradise park
# Processing Record 14 of Set 3 | pavlodar
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | shiguai
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | kendari
# Processing Record 21 of Set 3 | kittila
# Processing Record 22 of Set 3 | parfino
# Processing Record 23 of Set 3 | mount pearl
# Processing Record 24 of Set 3 | portland
# Processing Record 25 of Set 3 | emmett
# Processing Record 26 of Set 3 | arica
# Processing Record 27 of Set 3 | khvalynsk
# Processing Record 28 of Set 3 | forster
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | kone
# Processing Record 31 of Set 3 | atafu village
# Processing Record 32 of Set 3 | yermentau
# Processing Record 33 of Set 3 | mejit
# Processing Record 34 of Set 3 | bonthe
# Processing Record 35 of Set 3 | priladozhskiy
# Processing Record 36 of Set 3 | puerto natales
# Processing Record 37 of Set 3 | rongelap
# Processing Record 38 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | asau village
# City not found. Skipping...
# Processing Record 41 of Set 3 | badger
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | xiaoweizhai
# Processing Record 44 of Set 3 | hami
# Processing Record 45 of Set 3 | shingu
# Processing Record 46 of Set 3 | zyryanovsk
# Processing Record 47 of Set 3 | ad dawadimi
# Processing Record 48 of Set 3 | rakvere
# Processing Record 49 of Set 3 | cockburn town
# Processing Record 50 of Set 3 | east london
# Processing Record 1 of Set 4 | santa cruz
# Processing Record 2 of Set 4 | west island
# Processing Record 3 of Set 4 | parry sound
# Processing Record 4 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 5 of Set 4 | chonchi
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | gustavsberg
# Processing Record 8 of Set 4 | margate
# Processing Record 9 of Set 4 | silifke
# Processing Record 10 of Set 4 | altar
# Processing Record 11 of Set 4 | dunedin
# Processing Record 12 of Set 4 | callao
# Processing Record 13 of Set 4 | general cabrera
# Processing Record 14 of Set 4 | afaahiti
# Processing Record 15 of Set 4 | minas de marcona
# Processing Record 16 of Set 4 | tangier
# Processing Record 17 of Set 4 | santo antonio do taua
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 20 of Set 4 | pucallpa
# Processing Record 21 of Set 4 | conceicao da barra
# Processing Record 22 of Set 4 | bratslav
# Processing Record 23 of Set 4 | bereeda
# Processing Record 24 of Set 4 | portstewart
# Processing Record 25 of Set 4 | puerto san jose
# Processing Record 26 of Set 4 | myeik
# Processing Record 27 of Set 4 | midvagur
# Processing Record 28 of Set 4 | were ilu
# Processing Record 29 of Set 4 | ust-nera
# Processing Record 30 of Set 4 | quesnel
# Processing Record 31 of Set 4 | piti village
# Processing Record 32 of Set 4 | enewetak
# Processing Record 33 of Set 4 | qamdo
# Processing Record 34 of Set 4 | guarapuava
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | beeville
# Processing Record 37 of Set 4 | quellon
# Processing Record 38 of Set 4 | kotabumi
# Processing Record 39 of Set 4 | hammerfest
# Processing Record 40 of Set 4 | moranbah
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | sinmak
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | buka
# Processing Record 46 of Set 4 | ilha de mocambique
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | uglegorsk
# Processing Record 50 of Set 4 | tazovsky
# Processing Record 1 of Set 5 | ratnagiri
# Processing Record 2 of Set 5 | zyryanskoye
# Processing Record 3 of Set 5 | gadzhiyevo
# Processing Record 4 of Set 5 | kalmunai
# Processing Record 5 of Set 5 | eastlake
# Processing Record 6 of Set 5 | nabire
# Processing Record 7 of Set 5 | macau
# Processing Record 8 of Set 5 | san antonio de pale
# Processing Record 9 of Set 5 | villa gesell
# Processing Record 10 of Set 5 | abong mbang
# Processing Record 11 of Set 5 | holualoa
# Processing Record 12 of Set 5 | sao gabriel da cachoeira
# Processing Record 13 of Set 5 | mao
# Processing Record 14 of Set 5 | aasiaat
# Processing Record 15 of Set 5 | kirensk
# Processing Record 16 of Set 5 | wailua homesteads
# Processing Record 17 of Set 5 | mangai
# Processing Record 18 of Set 5 | linxia chengguanzhen
# Processing Record 19 of Set 5 | vernon
# Processing Record 20 of Set 5 | port alfred
# Processing Record 21 of Set 5 | pelabuhanratu
# Processing Record 22 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 5 | attapeu
# Processing Record 24 of Set 5 | tobelo
# Processing Record 25 of Set 5 | isangel
# Processing Record 26 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 27 of Set 5 | porto novo
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | bulayevo
# Processing Record 30 of Set 5 | faya-largeau
# Processing Record 31 of Set 5 | cloquet
# Processing Record 32 of Set 5 | howard springs
# Processing Record 33 of Set 5 | tiksi
# Processing Record 34 of Set 5 | flin flon
# Processing Record 35 of Set 5 | steinkjer
# Processing Record 36 of Set 5 | georgetown
# Processing Record 37 of Set 5 | arar
# Processing Record 38 of Set 5 | mahina
# Processing Record 39 of Set 5 | iskateley
# Processing Record 40 of Set 5 | manaure
# Processing Record 41 of Set 5 | sirte
# Processing Record 42 of Set 5 | tsetserleg
# Processing Record 43 of Set 5 | luau
# Processing Record 44 of Set 5 | port angeles
# Processing Record 45 of Set 5 | tindouf
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | namibe
# Processing Record 48 of Set 5 | guanare
# Processing Record 49 of Set 5 | xishan
# Processing Record 50 of Set 5 | kill devil hills
# Processing Record 1 of Set 6 | guijuelo
# Processing Record 2 of Set 6 | nizhneudinsk
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | nova russas
# Processing Record 5 of Set 6 | namdrik
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | tadine
# Processing Record 8 of Set 6 | vadso
# Processing Record 9 of Set 6 | soio
# Processing Record 10 of Set 6 | jayapura
# Processing Record 11 of Set 6 | zeya
# Processing Record 12 of Set 6 | al burayqah
# Processing Record 13 of Set 6 | midelt
# Processing Record 14 of Set 6 | saudarkrokur
# Processing Record 15 of Set 6 | byron bay
# Processing Record 16 of Set 6 | hadibu
# Processing Record 17 of Set 6 | nurabad
# Processing Record 18 of Set 6 | reggane
# Processing Record 19 of Set 6 | pimentel
# Processing Record 20 of Set 6 | sydney
# Processing Record 21 of Set 6 | nantucket
# Processing Record 22 of Set 6 | la passe
# Processing Record 23 of Set 6 | taksimo
# Processing Record 24 of Set 6 | siem reap
# Processing Record 25 of Set 6 | masterton
# Processing Record 26 of Set 6 | neiafu
# Processing Record 27 of Set 6 | al muwayh
# Processing Record 28 of Set 6 | suoyarvi
# Processing Record 29 of Set 6 | tauranga
# Processing Record 30 of Set 6 | polyarnyy
# Processing Record 31 of Set 6 | hoi an
# Processing Record 32 of Set 6 | valday
# Processing Record 33 of Set 6 | sanchor
# Processing Record 34 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 35 of Set 6 | bodaybo
# Processing Record 36 of Set 6 | egilsstadir
# Processing Record 37 of Set 6 | cabo san lucas
# Processing Record 38 of Set 6 | viqueque
# Processing Record 39 of Set 6 | nsanje
# Processing Record 40 of Set 6 | aland
# Processing Record 41 of Set 6 | yamada
# Processing Record 42 of Set 6 | kingston
# Processing Record 43 of Set 6 | bac lieu
# Processing Record 44 of Set 6 | knyaze-volkonskoye
# Processing Record 45 of Set 6 | yreka
# Processing Record 46 of Set 6 | nicoya
# Processing Record 47 of Set 6 | paita
# Processing Record 48 of Set 6 | dudinka
# Processing Record 49 of Set 6 | boden
# Processing Record 50 of Set 6 | gambela
# Processing Record 1 of Set 7 | bocas del toro
# Processing Record 2 of Set 7 | marshfield
# Processing Record 3 of Set 7 | zhigalovo
# Processing Record 4 of Set 7 | bosobolo
# Processing Record 5 of Set 7 | nizhnyaya poyma
# Processing Record 6 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 7 | lagoa
# Processing Record 8 of Set 7 | whitehorse
# Processing Record 9 of Set 7 | lospalos
# Processing Record 10 of Set 7 | kanazawa
# Processing Record 11 of Set 7 | wewak
# Processing Record 12 of Set 7 | plesetsk
# Processing Record 13 of Set 7 | wabag
# Processing Record 14 of Set 7 | san luis de la loma
# Processing Record 15 of Set 7 | queenstown
# Processing Record 16 of Set 7 | cannonvale
# Processing Record 17 of Set 7 | keflavik
# Processing Record 18 of Set 7 | urumqi
# Processing Record 19 of Set 7 | haiku-pauwela
# Processing Record 20 of Set 7 | uturoa
# Processing Record 21 of Set 7 | alice springs
# Processing Record 22 of Set 7 | kushiro
# Processing Record 23 of Set 7 | okhotsk
# Processing Record 24 of Set 7 | acarau
# Processing Record 25 of Set 7 | troy
# Processing Record 26 of Set 7 | tarhuna
# Processing Record 27 of Set 7 | conception bay south
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | luena
# Processing Record 30 of Set 7 | vallenar
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | udachny
# Processing Record 33 of Set 7 | muisne
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | labytnangi
# Processing Record 36 of Set 7 | panaba
# Processing Record 37 of Set 7 | yaring
# Processing Record 38 of Set 7 | zhaqsy
# Processing Record 39 of Set 7 | kataysk
# Processing Record 40 of Set 7 | sao joao da barra
# Processing Record 41 of Set 7 | saint croix
# Processing Record 42 of Set 7 | isfana
# Processing Record 43 of Set 7 | sligo
# Processing Record 44 of Set 7 | fort wellington
# Processing Record 45 of Set 7 | mil'kovo
# Processing Record 46 of Set 7 | conduaga
# Processing Record 47 of Set 7 | opuwo
# Processing Record 48 of Set 7 | luderitz
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | fauske
# Processing Record 1 of Set 8 | akureyri
# Processing Record 2 of Set 8 | kidal
# Processing Record 3 of Set 8 | tual
# Processing Record 4 of Set 8 | revelstoke
# Processing Record 5 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 6 of Set 8 | filey
# Processing Record 7 of Set 8 | kolwezi
# Processing Record 8 of Set 8 | plettenberg bay
# Processing Record 9 of Set 8 | pratt
# Processing Record 10 of Set 8 | diego de almagro
# Processing Record 11 of Set 8 | amga
# Processing Record 12 of Set 8 | mirny
# Processing Record 13 of Set 8 | aleg
# Processing Record 14 of Set 8 | kenai
# Processing Record 15 of Set 8 | roma
# Processing Record 16 of Set 8 | tamanrasset
# Processing Record 17 of Set 8 | lundazi
# Processing Record 18 of Set 8 | prince rupert
# Processing Record 19 of Set 8 | at taj
# Processing Record 20 of Set 8 | sao jose
# Processing Record 21 of Set 8 | camocim
# Processing Record 22 of Set 8 | ippy
# Processing Record 23 of Set 8 | inirida
# Processing Record 24 of Set 8 | yaren
# Processing Record 25 of Set 8 | bratsk
# Processing Record 26 of Set 8 | kerikeri
# Processing Record 27 of Set 8 | revda
# Processing Record 28 of Set 8 | sidi akkacha
# Processing Record 29 of Set 8 | sparta
# Processing Record 30 of Set 8 | rovnoye
# Processing Record 31 of Set 8 | kota kinabalu
# Processing Record 32 of Set 8 | bereket
# Processing Record 33 of Set 8 | nizhneangarsk
# Processing Record 34 of Set 8 | sinabang
# Processing Record 35 of Set 8 | carnarvon
# Processing Record 36 of Set 8 | suva
# Processing Record 37 of Set 8 | tabas
# Processing Record 38 of Set 8 | lebu
# Processing Record 39 of Set 8 | arvayheer
# Processing Record 40 of Set 8 | itoman
# Processing Record 41 of Set 8 | majuro
# Processing Record 42 of Set 8 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 43 of Set 8 | kapa'a
# Processing Record 44 of Set 8 | angaur state
# Processing Record 45 of Set 8 | sur
# Processing Record 46 of Set 8 | fort st. john
# Processing Record 47 of Set 8 | baghlan
# Processing Record 48 of Set 8 | silver city
# Processing Record 49 of Set 8 | qusmuryn
# Processing Record 50 of Set 8 | saint-philippe
# Processing Record 1 of Set 9 | khandyga
# Processing Record 2 of Set 9 | bedford
# Processing Record 3 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 9 | tangalle
# Processing Record 5 of Set 9 | severo-yeniseyskiy
# Processing Record 6 of Set 9 | phu ly
# Processing Record 7 of Set 9 | joigny
# Processing Record 8 of Set 9 | daru
# Processing Record 9 of Set 9 | funafuti
# Processing Record 10 of Set 9 | brookings
# Processing Record 11 of Set 9 | ngambe
# Processing Record 12 of Set 9 | vikhorevka
# Processing Record 13 of Set 9 | humberto de campos
# Processing Record 14 of Set 9 | vershino-darasunskiy
# Processing Record 15 of Set 9 | micheweni
# Processing Record 16 of Set 9 | beau vallon
# Processing Record 17 of Set 9 | marsa alam
# Processing Record 18 of Set 9 | ghat
# Processing Record 19 of Set 9 | nadym
# Processing Record 20 of Set 9 | undurkhaan
# Processing Record 21 of Set 9 | salamanca
# Processing Record 22 of Set 9 | alamosa
# Processing Record 23 of Set 9 | kununurra
# Processing Record 24 of Set 9 | ulsteinvik
# Processing Record 25 of Set 9 | broome
# Processing Record 26 of Set 9 | alofi
# Processing Record 27 of Set 9 | manicore
# Processing Record 28 of Set 9 | fale old settlement
# Processing Record 29 of Set 9 | eatonton
# Processing Record 30 of Set 9 | statesboro
# Processing Record 31 of Set 9 | atasu
# Processing Record 32 of Set 9 | beloyarskiy
# Processing Record 33 of Set 9 | saint-pierre
# Processing Record 34 of Set 9 | tchintabaraden
# Processing Record 35 of Set 9 | pitimbu
# Processing Record 36 of Set 9 | hafnarfjordur
# Processing Record 37 of Set 9 | arteche
# Processing Record 38 of Set 9 | taquaritinga
# Processing Record 39 of Set 9 | ulladulla
# Processing Record 40 of Set 9 | meadow lakes
# Processing Record 41 of Set 9 | coahuayana de hidalgo
# Processing Record 42 of Set 9 | puerto deseado
# Processing Record 43 of Set 9 | yucca valley
# Processing Record 44 of Set 9 | goundam
# Processing Record 45 of Set 9 | poxoreo
# Processing Record 46 of Set 9 | lata
# Processing Record 47 of Set 9 | islamorada
# Processing Record 48 of Set 9 | harstad
# Processing Record 49 of Set 9 | la asuncion
# Processing Record 50 of Set 9 | vila velha
# Processing Record 1 of Set 10 | jining
# Processing Record 2 of Set 10 | bayanaul
# Processing Record 3 of Set 10 | horta
# Processing Record 4 of Set 10 | meizhou
# Processing Record 5 of Set 10 | isoka
# Processing Record 6 of Set 10 | tanumah
# Processing Record 7 of Set 10 | flying fish cove
# Processing Record 8 of Set 10 | lompoc
# Processing Record 9 of Set 10 | doctor alberto oviedo mota
# Processing Record 10 of Set 10 | rehoboth
# Processing Record 11 of Set 10 | nova sintra
# Processing Record 12 of Set 10 | inda silase
# Processing Record 13 of Set 10 | lys'va
# Processing Record 14 of Set 10 | katima mulilo
# Processing Record 15 of Set 10 | hobyo
# Processing Record 16 of Set 10 | miramichi
# Processing Record 17 of Set 10 | merizo village
# Processing Record 18 of Set 10 | rancho palos verdes
# Processing Record 19 of Set 10 | laguna
# Processing Record 20 of Set 10 | kampong speu
# Processing Record 21 of Set 10 | pankovka
# Processing Record 22 of Set 10 | mount gambier
# Processing Record 23 of Set 10 | karasu
# Processing Record 24 of Set 10 | vorkuta
# Processing Record 25 of Set 10 | westerland
# Processing Record 26 of Set 10 | moyynkum
# Processing Record 27 of Set 10 | arkhangel'sk
# Processing Record 28 of Set 10 | watsa
# Processing Record 29 of Set 10 | volgorechensk
# Processing Record 30 of Set 10 | caleta de carquin
# Processing Record 31 of Set 10 | baise city
# Processing Record 32 of Set 10 | falenki
# Processing Record 33 of Set 10 | vilyuchinsk
# Processing Record 34 of Set 10 | asahi
# Processing Record 35 of Set 10 | morondava
# Processing Record 36 of Set 10 | tropea
# Processing Record 37 of Set 10 | monticello
# Processing Record 38 of Set 10 | autun
# Processing Record 39 of Set 10 | naama
# Processing Record 40 of Set 10 | mhamid
# Processing Record 41 of Set 10 | madang
# Processing Record 42 of Set 10 | hell-ville
# Processing Record 43 of Set 10 | athens
# Processing Record 44 of Set 10 | bhadrachalam
# Processing Record 45 of Set 10 | manta
# Processing Record 46 of Set 10 | salinopolis
# Processing Record 47 of Set 10 | malvan
# Processing Record 48 of Set 10 | metlili chaamba
# Processing Record 49 of Set 10 | puerto lleras
# Processing Record 50 of Set 10 | sibay
# Processing Record 1 of Set 11 | nova olimpia
# Processing Record 2 of Set 11 | canon city
# Processing Record 3 of Set 11 | arris
# Processing Record 4 of Set 11 | sant'antioco
# Processing Record 5 of Set 11 | bardai
# Processing Record 6 of Set 11 | salaberry-de-valleyfield
# Processing Record 7 of Set 11 | konosha
# Processing Record 8 of Set 11 | srikakulam
# Processing Record 9 of Set 11 | hoquiam
# Processing Record 10 of Set 11 | znamensk
# Processing Record 11 of Set 11 | puerto colombia
# Processing Record 12 of Set 11 | salekhard
# Processing Record 13 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 14 of Set 11 | freguesia do ribeirao da ilha
# Processing Record 15 of Set 11 | shimoda
# Processing Record 16 of Set 11 | tsiombe
# Processing Record 17 of Set 11 | kodinsk
# Processing Record 18 of Set 11 | machico
# Processing Record 19 of Set 11 | mezhdurechenskiy
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | camayenne
# Processing Record 22 of Set 11 | hacienda huancane
# Processing Record 23 of Set 11 | tralee
# Processing Record 24 of Set 11 | belyy yar
# Processing Record 25 of Set 11 | kerema
# Processing Record 26 of Set 11 | fada
# Processing Record 27 of Set 11 | chu
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | guiuan
# Processing Record 30 of Set 11 | chibougamau
# Processing Record 31 of Set 11 | pabrade
# Processing Record 32 of Set 11 | nanao
# Processing Record 33 of Set 11 | cozumel
# Processing Record 34 of Set 11 | tafuna
# Processing Record 35 of Set 11 | xilin hot
# Processing Record 36 of Set 11 | ushachy
# Processing Record 37 of Set 11 | labrador city
# Processing Record 38 of Set 11 | president roxas
# Processing Record 39 of Set 11 | haimen
# Processing Record 40 of Set 11 | yuanping
# Processing Record 41 of Set 11 | al jawf
# Processing Record 42 of Set 11 | nguigmi
# Processing Record 43 of Set 11 | pointe michel
# Processing Record 44 of Set 11 | pocone
# Processing Record 45 of Set 11 | howrah
# Processing Record 46 of Set 11 | happy valley-goose bay
# Processing Record 47 of Set 11 | chinchilla
# Processing Record 48 of Set 11 | bandarbeyla
# Processing Record 49 of Set 11 | ringkobing
# Processing Record 50 of Set 11 | lisala
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | pacasmayo
# Processing Record 3 of Set 12 | sungailiat
# Processing Record 4 of Set 12 | lenino
# Processing Record 5 of Set 12 | murun-kuren
# Processing Record 6 of Set 12 | mount darwin
# Processing Record 7 of Set 12 | mount pleasant
# Processing Record 8 of Set 12 | zaragoza
# Processing Record 9 of Set 12 | lucapa
# Processing Record 10 of Set 12 | chui
# Processing Record 11 of Set 12 | kawambwa
# Processing Record 12 of Set 12 | afua
# Processing Record 13 of Set 12 | podporozh'ye
# Processing Record 14 of Set 12 | kuta
# Processing Record 15 of Set 12 | saldanha
# Processing Record 16 of Set 12 | tanjung selor
# City not found. Skipping...
# Processing Record 17 of Set 12 | kasongo
# Processing Record 18 of Set 12 | nikolayevsk-on-amure
# Processing Record 19 of Set 12 | katsuura
# Processing Record 20 of Set 12 | pikeville
# Processing Record 21 of Set 12 | toliara
# Processing Record 22 of Set 12 | fortaleza
# Processing Record 23 of Set 12 | mweka
# Processing Record 24 of Set 12 | magadan
# Processing Record 25 of Set 12 | ejea de los caballeros
# Processing Record 26 of Set 12 | melekeok village
# Processing Record 27 of Set 12 | kinkala
# Processing Record 28 of Set 12 | balod
# Processing Record 29 of Set 12 | natal
# Processing Record 30 of Set 12 | oum hadjer
# Processing Record 31 of Set 12 | los andes
# Processing Record 32 of Set 12 | camana
# Processing Record 33 of Set 12 | adam
# Processing Record 34 of Set 12 | springbok
# Processing Record 35 of Set 12 | al mayadin
# Processing Record 36 of Set 12 | mili
# Processing Record 37 of Set 12 | maine soroa
# Processing Record 38 of Set 12 | okha
# Processing Record 39 of Set 12 | bonab
# Processing Record 40 of Set 12 | hanceville
# Processing Record 41 of Set 12 | pierre
# Processing Record 42 of Set 12 | kingscliff
# Processing Record 43 of Set 12 | catriel
# Processing Record 44 of Set 12 | mariental
# Processing Record 45 of Set 12 | ardakan
# Processing Record 46 of Set 12 | hotan
# Processing Record 47 of Set 12 | shalazhi
# Processing Record 48 of Set 12 | hovd
# Processing Record 49 of Set 12 | mukalla
# Processing Record 50 of Set 12 | palmwoods
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167     42.06        89         100
# 1             dakhla  23.6848  -15.9580     71.62        73          89
# 2          grytviken -54.2811  -36.5092     33.75        82          96
# 3          adamstown -25.0660 -130.1015     71.80        77          61
# 4             taybad  34.7400   60.7756     78.44        23          45
#
#    Wind Speed Country        Date
# 0       25.70      TF  05/06/2024
# 1       26.46      EH  05/06/2024
# 2       10.18      GS  05/06/2024
# 3       21.43      PN  05/06/2024
# 4        4.45      IR  05/06/2024

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167     42.06        89         100
# 1                   dakhla  23.6848  -15.9580     71.62        73          89
# 2                grytviken -54.2811  -36.5092     33.75        82          96
# 3                adamstown -25.0660 -130.1015     71.80        77          61
# 4                   taybad  34.7400   60.7756     78.44        23          45
#
#          Wind Speed Country        Date
# City_ID
# 0             25.70      TF  05/06/2024
# 1             26.46      EH  05/06/2024
# 2             10.18      GS  05/06/2024
# 3             21.43      PN  05/06/2024
# 4              4.45      IR  05/06/2024

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Max Temp', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude .vs Max Temperature (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Max Temperature (F)"
                 )

# Save the figure
plt.savefig("output_data/Scatter_Lat_vs_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Humidity', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Humidity (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Humidity (%)"
                 )

# Save the figure
plt.savefig("output_data/Scatter_Lat_vs_hum.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Cloudiness', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Cloudiness (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Cloudiness (%)"
                 )

# Save the figure
plt.savefig("output_data/scatter_lat_vs_cld.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
# Incorporate the other graph properties
city_data_df.plot(kind="scatter", x='Lat', y='Wind Speed', s=60, color='lightblue', edgecolor='black', 
                  title=("City Latitude vs. Wind Speed (" + city_date + ")"), xlabel="Latitude", 
                  ylabel="Wind Speed (mph)"
                 )

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def Lin_Reg_Plt(df, x, y):
    x_values = df[x]
    y_values = df[y]
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    rvalue = round(rvalue, 3)
    
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values, s=60, color='darkcyan', edgecolor='black')
    
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.5, 0.1), xycoords='axes fraction', fontsize=15,color="red", ha='center', va='bottom')

    plt.xlabel('Latitude')
    plt.ylabel(y)
    print("The r-value is: " + str(rvalue))
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
n_hemi_city_data_df = city_data_df.loc[city_data_df['Lat']  >= 0]

# Display sample data
n_hemi_city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             dakhla  23.6848  -15.9580     71.62        73          89
# 4             taybad  34.7400   60.7756     78.44        23          45
# 5        yellowknife  62.4560 -114.3525     57.42        57          20
# 11           susuman  62.7833  148.1667     26.98        86          77
# 14           klyuchi  52.2667   79.1667     44.06        47          41
#
#          Wind Speed Country        Date
# City_ID
# 1             26.46      EH  05/06/2024
# 4              4.45      IR  05/06/2024
# 5              9.22      CA  05/06/2024
# 11             1.01      RU  05/06/2024
# 14             2.95      RU  05/06/2024

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
s_hemi_city_data_df = city_data_df.loc[city_data_df['Lat']  < 0]

# Display sample data
s_hemi_city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                  port-aux-francais -49.3500   70.2167     42.06        89
# 2                          grytviken -54.2811  -36.5092     33.75        82
# 3                          adamstown -25.0660 -130.1015     71.80        77
# 6                          papatowai -46.5619  169.4708     46.29        76
# 7        edinburgh of the seven seas -37.0676  -12.3116     57.06        65
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100       25.70      TF  05/06/2024
# 2                96       10.18      GS  05/06/2024
# 3                61       21.43      PN  05/06/2024
# 6                94       11.99      NZ  05/06/2024
# 7                24       23.33      SH  05/06/2024

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat' ,'Max Temp')
# Out:
# The r-value is: -0.863

# %%
# Linear regression on Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat' ,'Max Temp')
# Out:
# The r-value is: 0.792

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Temperature.  The data points show that Temperature rises as the Latitude gets closer to 0 (equator).  The R-values show quantitatively that there is a high correlation between Temperature and Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Humidity')
# Out:
# The r-value is: 0.147

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Humidity')
# Out:
# The r-value is: 0.081

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Humidity. There are more data points for Humidity above 50 than below and looks to be evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Humidity and Latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.09

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.192

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Latitude and Cloudiness. The highest concentration of Cloudiness data is at 0 and 100 and looks evenly disbursed over the Latitude range.  The R-values show quantitatively that there is a week correlation between Cloudiness and Latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Lin_Reg_Plt(n_hemi_city_data_df ,'Lat', 'Wind Speed')
# Out:
# The r-value is: -0.055

# %%
# Southern Hemisphere
Lin_Reg_Plt(s_hemi_city_data_df ,'Lat', 'Wind Speed')
# Out:
# The r-value is: -0.045

# %% [markdown]
# **Discussion about the linear relationship:** The two scatter plots above show the relationship between Wind Speed and Humidity. The volume of data points for Wind Speed decreases above 15 and looks to be evenly disbursed over the Latitude range.  The R-values show quantitatively that there is no correlation between Wind Speed and Latitude.
